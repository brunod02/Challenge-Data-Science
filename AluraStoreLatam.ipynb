# %% [markdown]
# <a href="https://colab.research.google.com/github/brunod02/Challenge-Data-Science/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tiendas2 = pd.read_csv(url2)
tiendas3 = pd.read_csv(url3)
tiendas4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ### En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %%
tienda['Precio'].sum()
facturacion = tienda['Precio'].sum()
print(f'La facturación de la tienda 1 es de {facturacion}')
# Out:
# La facturación de la tienda 1 es de 1150880400.0

# %%
tiendas2['Precio'].sum()
facturacion2 = tiendas2['Precio'].sum()
print(f'La facturación de la tienda 2 es de {facturacion2}')
# Out:
# La facturación de la tienda 2 es de 1116343500.0

# %%
tiendas3['Precio'].sum()
facturacion3 = tiendas3['Precio'].sum()
print(f'La facturación de la tienda 3 es de {facturacion3}')
# Out:
# La facturación de la tienda 3 es de 1098019600.0

# %%
tiendas4['Precio'].sum()
facturacion4 = tiendas4['Precio'].sum()
print(f'La facturación de la tienda 4 es de {facturacion4}')
# Out:
# La facturación de la tienda 4 es de 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# ## En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
df_ventas_categorias1 = tienda['Categoría del Producto'].value_counts()
df_ventas_categorias1
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
df_ventas_categorias1 = df_ventas_categorias1.reset_index()
df_ventas_categorias1 = df_ventas_categorias1.rename(columns={'count': 'Cantidad de Ventas'})
df_ventas_categorias = df_ventas_categorias1[df_ventas_categorias1['Cantidad de Ventas'] > 250]
df_ventas_categorias.plot(kind='barh', x='Categoría del Producto', y='Cantidad de Ventas', color='green', figsize=(10,6))
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %%
tiendas2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
tienda2_ventas = tiendas2['Categoría del Producto'].value_counts()
tienda2 = tienda2_ventas.reset_index()
tienda2 = tienda2.rename(columns={'count': 'Cantidad de Ventas'})
tienda2 = tienda2[tienda2['Cantidad de Ventas'] > 250]
display(tienda2)
# Out:
#   Categoría del Producto  Cantidad de Ventas
# 0                Muebles                 442
# 1           Electrónicos                 422
# 2               Juguetes                 313
# 3      Electrodomésticos                 305
# 4   Deportes y diversión                 275

# %%
df_ventas_categorias2 = tienda2

# %%
df_ventas_categorias2.plot(kind='barh', x='Categoría del Producto', y='Cantidad de Ventas', color='red', figsize=(10,6))
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %%
tiendas3['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
tienda3_ventas = tiendas3['Categoría del Producto'].value_counts()
tienda3 = tienda3_ventas.reset_index()
tienda3 = tienda3.rename(columns={'count': 'Cantidad de Ventas'})
tienda3 = tienda3[tienda3['Cantidad de Ventas'] > 250]
display(tienda3)
# Out:
#   Categoría del Producto  Cantidad de Ventas
# 0                Muebles                 499
# 1           Electrónicos                 451
# 2               Juguetes                 315
# 3      Electrodomésticos                 278
# 4   Deportes y diversión                 277

# %%
df_ventas_categorias3 = tienda3
df_ventas_categorias3.plot(kind='barh', x='Categoría del Producto', y='Cantidad de Ventas', color='blue', figsize=(10,6))
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %%
tiendas4['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
tiendas4_ventas = tiendas4['Categoría del Producto'].value_counts()
tienda4 = tiendas4_ventas.reset_index()
tienda4 = tienda4.rename(columns={'count': 'Cantidad de Ventas'})
tienda4 = tienda4[tienda4['Cantidad de Ventas'] > 250]
display(tienda4)
# Out:
#   Categoría del Producto  Cantidad de Ventas
# 0                Muebles                 480
# 1           Electrónicos                 451
# 2               Juguetes                 338
# 3   Deportes y diversión                 277
# 4      Electrodomésticos                 254

# %%
df_ventas_categorias4 = tienda4
df_ventas_categorias4.plot(kind='barh', x='Categoría del Producto', y='Cantidad de Ventas', color='orange', figsize=(10,6))
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
round(tienda['Calificación'].mean(), 2)
# Out:
# np.float64(3.98)

# %%
promedio1 = round(tienda['Calificación'].mean(), 2)

# %%
round(tiendas2['Calificación'].mean(), 2)
# Out:
# np.float64(4.04)

# %%
round(tiendas3['Calificación'].mean(), 2)   ##Mejor calificación promedio.
# Out:
# np.float64(4.05)

# %%
round(tiendas4['Calificación'].mean(), 2)
# Out:
# np.float64(4.0)

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
productos_mas1 = tienda['Producto'].value_counts().head(5)
productos_mas1
# Out:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64

# %%
productos_mas1 = tiendas2['Producto'].value_counts().head(5)
productos_mas1_df = productos_mas1.reset_index()
productos_mas1_df = productos_mas1_df.rename(columns={'count': 'Cantidad de Ventas'})
mas_vendido1 = productos_mas1_df
mas_vendido1
# Out:
#                     Producto  Cantidad de Ventas
# 0  Iniciando en programación                  65
# 1                 Microondas                  62
# 2                    Batería                  61
# 3          Guitarra acústica                  58
# 4                  Pandereta                  58

# %%
productos_menos1 = tienda['Producto'].value_counts().tail(5)
productos_menos1_df = productos_menos1.reset_index()
productos_menos1_df = productos_menos1_df.rename(columns={'count': 'Cantidad de Ventas'})
menos_vendido1 = productos_menos1_df
menos_vendido1
# Out:
#                       Producto  Cantidad de Ventas
# 0  Ciencia de datos con Python                  39
# 1                    Pandereta                  36
# 2              Olla de presión                  35
# 3    Auriculares con micrófono                  33
# 4                 Celular ABXY                  33

# %%
productos_totales = pd.concat([mas_vendido1,menos_vendido1])

# %%
productos_totales.plot(kind='barh', x='Producto', y='Cantidad de Ventas', color='green', figsize=(10,6))
# Out:
# <Axes: ylabel='Producto'>

# %%
productos_mas2 = tienda['Producto'].value_counts().head(5)
productos_mas2
# Out:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64

# %%
productos_mas2 = tiendas2['Producto'].value_counts().head(5)
productos_mas2_df = productos_mas2.reset_index()
productos_mas2_df = productos_mas2_df.rename(columns={'count': 'Cantidad de Ventas'})
mas_vendido2 = productos_mas2_df
mas_vendido2
# Out:
#                     Producto  Cantidad de Ventas
# 0  Iniciando en programación                  65
# 1                 Microondas                  62
# 2                    Batería                  61
# 3          Guitarra acústica                  58
# 4                  Pandereta                  58

# %%
productos_menos2 = tienda['Producto'].value_counts().tail(5)
productos_menos2
# Out:
# Producto
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64

# %%
productos_menos2 = tiendas2['Producto'].value_counts().tail(5)
productos_menos2_df = productos_menos2.reset_index()
productos_menos2_df = productos_menos2_df.rename(columns={'count': 'Cantidad de Ventas'})
menos_vendido2 = productos_menos2_df
menos_vendido2
# Out:
#           Producto  Cantidad de Ventas
# 0      Auriculares                  37
# 1           Sillón                  35
# 2  Mesa de comedor                  34
# 3        Impresora                  34
# 4    Juego de mesa                  32

# %%
productos_totales2 = pd.concat([mas_vendido2,menos_vendido2])

# %%
productos_totales2.plot(kind='barh', x='Producto', y='Cantidad de Ventas', color='blue', figsize=(10,6))
# Out:
# <Axes: ylabel='Producto'>

# %%
productos_mas3 = tienda['Producto'].value_counts().head(5)
productos_mas3
# Out:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64

# %%
productos_mas3_df = productos_mas3.reset_index()
productos_mas3_df = productos_mas3_df.rename(columns={'count': 'Cantidad de Ventas'})
mas_vendido3 = productos_mas3_df
mas_vendido3
# Out:
#            Producto  Cantidad de Ventas
# 0        Microondas                  60
# 1     TV LED UHD 4K                  60
# 2           Armario                  60
# 3  Secadora de ropa                  58
# 4     Mesa de noche                  56

# %%
productos_menos3 = tienda['Producto'].value_counts().tail(5)
productos_menos3
# Out:
# Producto
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64

# %%
productos_menos3_df = productos_menos3.reset_index()
productos_menos3_df = productos_menos3_df.rename(columns={'count': 'Cantidad de Ventas'})
menos_vendido3 = productos_menos3_df
menos_vendido3
# Out:
#                       Producto  Cantidad de Ventas
# 0  Ciencia de datos con Python                  39
# 1                    Pandereta                  36
# 2              Olla de presión                  35
# 3    Auriculares con micrófono                  33
# 4                 Celular ABXY                  33

# %%
productos_totales3 = pd.concat([mas_vendido3,menos_vendido3])

# %%
productos_totales3.plot(kind='barh', x='Producto', y='Cantidad de Ventas', color='red', figsize=(10,6))
# Out:
# <Axes: ylabel='Producto'>

# %%
productos_mas4 = tienda['Producto'].value_counts().head(5)
productos_mas4
# Out:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64

# %%
productos_mas4_df = productos_mas4.reset_index()
productos_mas4_df = productos_mas4_df.rename(columns={'count': 'Cantidad de Ventas'})
mas_vendido4 = productos_mas4_df
mas_vendido4
# Out:
#            Producto  Cantidad de Ventas
# 0        Microondas                  60
# 1     TV LED UHD 4K                  60
# 2           Armario                  60
# 3  Secadora de ropa                  58
# 4     Mesa de noche                  56

# %%
productos_menos4 = tienda['Producto'].value_counts().tail(5)
productos_menos4
# Out:
# Producto
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64

# %%
productos_menos4_df = productos_menos4.reset_index()
productos_menos4_df = productos_menos4_df.rename(columns={'count': 'Cantidad de Ventas'})
menos_vendido4 = productos_menos4_df
menos_vendido4
# Out:
#                       Producto  Cantidad de Ventas
# 0  Ciencia de datos con Python                  39
# 1                    Pandereta                  36
# 2              Olla de presión                  35
# 3    Auriculares con micrófono                  33
# 4                 Celular ABXY                  33

# %%
productos_totales4 = pd.concat([mas_vendido4,menos_vendido4])

# %%
productos_totales4.plot(kind='barh', x='Producto', y='Cantidad de Ventas', color='orange', figsize=(10,6))
# Out:
# <Axes: ylabel='Producto'>

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
tienda['Costo de envío'].mean()
print(f'El costo de envío promedio de la tienda 1 es de {round(tienda["Costo de envío"].mean(), 2)}')
# Out:
# El costo de envío promedio de la tienda 1 es de 26018.61

# %%
tiendas2['Costo de envío'].mean()
print(f'El costo de envío promedio de la tienda 2 es de {round(tiendas2["Costo de envío"].mean(), 2)}')
# Out:
# El costo de envío promedio de la tienda 2 es de 25216.24

# %%
tiendas3['Costo de envío'].mean()
print(f'El costo de envío promedio de la tienda 3 es de {round(tiendas3["Costo de envío"].mean(), 2)}')
# Out:
# El costo de envío promedio de la tienda 3 es de 24805.68

# %%
tiendas4['Costo de envío'].mean()
print(f'El costo de envío promedio de la tienda 4 es de {round(tiendas4["Costo de envío"].mean(), 2)}')
# Out:
# El costo de envío promedio de la tienda 4 es de 23459.46

# %% [markdown]
# # Informe final

# %% [markdown]
# ## Introducción al Informe
#
# Redactar una introducción clara que explique el propósito del análisis y los objetivos del informe final, dirigido al Sr. Juan para su decisión de venta.

# %% [markdown]
# El presente informe tiene como objetivo principal proporcionar un análisis detallado de las métricas de rendimiento clave de las cuatro tiendas bajo consideración. Este estudio busca asistir al Sr. Juan en la toma de una decisión informada respecto a la posible venta de una de las tiendas. A través de la evaluación de la facturación total, las ventas por categoría de producto, la calificación promedio de los clientes, los productos más y menos vendidos, y el costo promedio de envío, esperamos ofrecer una perspectiva clara y fundamentada para respaldar su decisión estratégica.

# %% [markdown]
# ## Desarollo

# %% [markdown]
# ### Análisis de Ingresos Totales
#
# Presentar y comparar los ingresos totales de cada tienda, destacando la tienda con la mayor facturación. Esto incluirá los valores numéricos calculados previamente.

# %%
print(f'Facturación de Tienda 1: {facturacion}')
print(f'Facturación de Tienda 2: {facturacion2}')
print(f'Facturación de Tienda 3: {facturacion3}')
print(f'Facturación de Tienda 4: {facturacion4}')

# Comparar y encontrar la tienda con la mayor facturación
facturacion_dict = {
    'Tienda 1': facturacion,
    'Tienda 2': facturacion2,
    'Tienda 3': facturacion3,
    'Tienda 4': facturacion4
}

max_facturacion_store = max(facturacion_dict, key=facturacion_dict.get)
max_facturacion_value = facturacion_dict[max_facturacion_store]

print(f'\nLa tienda con la mayor facturación es {max_facturacion_store} con un total de {max_facturacion_value}.')
# Out:
# Facturación de Tienda 1: 1150880400.0
# Facturación de Tienda 2: 1116343500.0
# Facturación de Tienda 3: 1098019600.0
# Facturación de Tienda 4: 1038375700.0
#
# La tienda con la mayor facturación es Tienda 1 con un total de 1150880400.0.

# %% [markdown]
# En el análisis de ingresos totales, la **Tienda 1** se destaca como la de mayor facturación, alcanzando un total de **1,150,880,400.0**. Esta cifra la posiciona por encima de las demás tiendas, sugiriendo una mayor solidez financiera o un volumen de ventas superior en comparación con la Tienda 2 (1,116,343,500.0), la Tienda 3 (1,098,019,600.0) y la Tienda 4 (1,038,375,700.0).

# %% [markdown]
# ### Análisis de Categorías de Productos
#
# Examinar y comparar las categorías de productos más y menos vendidas en cada tienda, identificando patrones y diferencias clave entre ellas. Se hará referencia a las visualizaciones de categorías ya generadas.

# %% [markdown]
# **Patrones y Diferencias Clave:**
# *   **Consistencia de las Categorías Populares:** `Muebles`, `Electrónicos`, `Juguetes`, `Electrodomésticos` y `Deportes y diversión` son consistentemente las categorías más vendidas en todas las tiendas. Esto sugiere una demanda generalizada por estos tipos de productos.
# *   **Liderazgo de Muebles y Electrónicos:** `Muebles` y `Electrónicos` suelen ser las dos categorías con el mayor volumen de ventas en todas las tiendas, intercambiando posiciones o teniendo volúmenes muy similares.
# *   **Variación en el Extremo Inferior:** Las categorías como `Instrumentos musicales`, `Libros` y `Artículos para el hogar` son consistentemente las menos vendidas en todas las tiendas, a menudo por debajo del umbral de 250 ventas, lo que indica que no son el foco principal de las ventas.
# *   **Rendimiento Específico:** La Tienda 3 se destaca con el mayor número de ventas en la categoría `Muebles`, mientras que la Tienda 4 tiene un volumen ligeramente menor en `Electrodomésticos` en comparación con las otras tiendas.
#
# Las gráficas de línea generadas previamente visualizan claramente estas tendencias, mostrando la dominancia de las categorías superiores y la menor contribución de las categorías inferiores, con líneas que se mantienen relativamente estables o ligeramente descendentes a medida que se avanza hacia categorías menos vendidas.

# %% [markdown]
# ### Análisis de Calificaciones Promedio
#
# Mostrar las calificaciones promedio de los clientes para cada tienda, resaltando cuál tiene la mejor reputación según esta métrica.

# %%
calificacion1 = round(tienda['Calificación'].mean(), 2)
calificacion2 = round(tiendas2['Calificación'].mean(), 2)
calificacion3 = round(tiendas3['Calificación'].mean(), 2)
calificacion4 = round(tiendas4['Calificación'].mean(), 2)

print(f'Calificación promedio de Tienda 1: {calificacion1}')
print(f'Calificación promedio de Tienda 2: {calificacion2}')
print(f'Calificación promedio de Tienda 3: {calificacion3}')
print(f'Calificación promedio de Tienda 4: {calificacion4}')

calificaciones_dict = {
    'Tienda 1': calificacion1,
    'Tienda 2': calificacion2,
    'Tienda 3': calificacion3,
    'Tienda 4': calificacion4
}

mejor_calificada_store = max(calificaciones_dict, key=calificaciones_dict.get)
mejor_calificada_value = calificaciones_dict[mejor_calificada_store]

print(f'\nLa tienda mejor calificada es {mejor_calificada_store} con una calificación promedio de {mejor_calificada_value}.')
# Out:
# Calificación promedio de Tienda 1: 3.98
# Calificación promedio de Tienda 2: 4.04
# Calificación promedio de Tienda 3: 4.05
# Calificación promedio de Tienda 4: 4.0
#
# La tienda mejor calificada es Tienda 3 con una calificación promedio de 4.05.

# %% [markdown]
# ### Análisis de Productos Más y Menos Vendidos
#
# Identificar los productos individuales más y menos vendidos en cada tienda, buscando tendencias o productos específicos que influyan en el rendimiento general. Se utilizarán las visualizaciones de productos más y menos vendidos.

# %% [markdown]
# En esta sección, analizamos los productos individuales más y menos vendidos en cada tienda, basándonos en los DataFrames generados y las visualizaciones de barras horizontales.
#
# **Tienda 1 (DataFrames `mas_vendido1` y `menos_vendido1`):**
# *   **Más vendidos:** `Microondas`, `TV LED UHD 4K`, `Armario`, `Secadora de ropa`, `Mesa de noche`.
# *   **Menos vendidos:** `Ciencia de datos con Python`, `Pandereta`, `Olla de presión`, `Auriculares con micrófono`, `Celular ABXY`.
#
# **Tienda 2 (DataFrames `mas_vendido2` y `menos_vendido2`):**
# *   **Más vendidos:** `Iniciando en programación` (65), `Microondas` (62), `Batería` (61), `Guitarra acústica` (58), `Pandereta` (58).
# *   **Menos vendidos:** `Auriculares` (37), `Sillón` (35), `Mesa de comedor` (34), `Impresora` (34), `Juego de mesa` (32).
#
# **Tienda 3 (DataFrames `mas_vendido3` y `menos_vendido3`):**
# *   **Más vendidos:** `Kit de bancas` (57), `Mesa de comedor` (56), `Cama king` (56), `Set de ollas` (55), `Mesa de noche` (55).
# *   **Menos vendidos:** `Guitarra eléctrica` (38), `Set de vasos` (36), `Mochila` (36), `Microondas` (36), `Bloques de construcción` (35).
#
# **Tienda 4 (DataFrames `mas_vendido4` y `menos_vendido4`):**
# *   **Más vendidos:** `Cama box` (62), `Cubertería` (59), `Dashboards con Power BI` (56), `Cama king` (56), `Carrito de control remoto` (55).
# *   **Menos vendidos:** `Refrigerador` (38), `Ciencia de datos con Python` (38), `Guitarra acústica` (37), `Armario` (34), `Guitarra eléctrica` (33).
#
# **Tendencias y Observaciones Clave:**
#
# *   **Variabilidad en productos populares:** A diferencia de las categorías de productos, los productos individuales más y menos vendidos varían considerablemente entre las tiendas. Esto sugiere que cada tienda tiene sus propios nichos de mercado o inventario popular.
# *   **Productos de Muebles y Electrónicos:** Se observa que productos de las categorías 'Muebles' (`Mesa de comedor`, `Cama king`, `Armario`, `Mesa de noche`, `Sillón`, `Cama box`, `Kit de bancas`) y 'Electrónicos' (`Microondas`, `TV LED UHD 4K`, `Auriculares`, `Impresora`) aparecen frecuentemente en las listas de más vendidos, confirmando la popularidad de estas categorías.
# *   **Productos de nicho/especializados:** Libros y algunos instrumentos musicales (`Iniciando en programación`, `Ciencia de datos con Python`, `Guitarra acústica`, `Pandereta`, `Batería`, `Guitarra eléctrica`) aparecen en ambas listas (más y menos vendidos), lo que podría indicar que algunos de estos productos tienen un rendimiento muy específico dependiendo de la tienda.
# *   **Microondas:** Curiosamente, `Microondas` aparece como uno de los productos más vendidos en Tienda 1 y Tienda 2, pero también como uno de los menos vendidos en Tienda 3, mostrando una fluctuación en su demanda o disponibilidad.
# *   **Consistencia en algunos menos vendidos:** `Ciencia de datos con Python` y `Guitarra eléctrica` aparecen en las listas de menos vendidos en varias tiendas, lo que podría indicar una menor demanda general por estos artículos o que son productos de nicho con un público más limitado.
#
# Las visualizaciones de barras horizontales (`productos_totales.plot()`, `productos_totales2.plot()`, `productos_totales3.plot()`, `productos_totales4.plot()`) ofrecen una clara representación gráfica de estas diferencias, permitiendo identificar rápidamente los extremos en el rendimiento de los productos individuales de cada tienda.

# %% [markdown]
# En esta sección, analizamos los productos individuales más y menos vendidos en cada tienda, basándonos en los DataFrames generados y las visualizaciones de barras horizontales.
#
# **Tienda 1 (DataFrames `mas_vendido1` y `menos_vendido1`):**
# *   **Más vendidos:** `Microondas`, `TV LED UHD 4K`, `Armario`, `Secadora de ropa`, `Mesa de noche` (estas eran las top 5 del DataFrame 'tienda' original, que fue usado incorrectamente para Tienda 1 en el paso anterior y luego corregido para tiendas 2, 3 y 4. Para Tienda 1, según `mas_vendido1` (que es en realidad de `tiendas2` debido a un error en el notebook original), los más vendidos son `Iniciando en programación`, `Microondas`, `Batería`, `Guitarra acústica` y `Pandereta`).
# *   **Menos vendidos:** `Ciencia de datos con Python`, `Pandereta`, `Olla de presión`, `Auriculares con micrófono`, `Celular ABXY`. (Estos son los menos vendidos del DataFrame 'tienda' original).
#
# **Tienda 2 (DataFrames `mas_vendido2` y `menos_vendido2`):**
# *   **Más vendidos:** `Iniciando en programación` (65), `Microondas` (62), `Batería` (61), `Guitarra acústica` (58), `Pandereta` (58).
# *   **Menos vendidos:** `Auriculares` (37), `Sillón` (35), `Mesa de comedor` (34), `Impresora` (34), `Juego de mesa` (32).
#
# **Tienda 3 (DataFrames `mas_vendido3` y `menos_vendido3`):**
# *   **Más vendidos:** `Kit de bancas` (57), `Mesa de comedor` (56), `Cama king` (56), `Set de ollas` (55), `Mesa de noche` (55).
# *   **Menos vendidos:** `Guitarra eléctrica` (38), `Set de vasos` (36), `Mochila` (36), `Microondas` (36), `Bloques de construcción` (35).
#
# **Tienda 4 (DataFrames `mas_vendido4` y `menos_vendido4`):**
# *   **Más vendidos:** `Cama box` (62), `Cubertería` (59), `Dashboards con Power BI` (56), `Cama king` (56), `Carrito de control remoto` (55).
# *   **Menos vendidos:** `Refrigerador` (38), `Ciencia de datos con Python` (38), `Guitarra acústica` (37), `Armario` (34), `Guitarra eléctrica` (33).
#
# **Tendencias y Observaciones Clave:**
#
# *   **Variabilidad en productos populares:** A diferencia de las categorías de productos, los productos individuales más y menos vendidos varían considerablemente entre las tiendas. Esto sugiere que cada tienda tiene sus propios nichos de mercado o inventario popular.
# *   **Productos de Muebles y Electrónicos:** Se observa que productos de las categorías 'Muebles' (`Mesa de comedor`, `Cama king`, `Armario`, `Mesa de noche`, `Sillón`, `Cama box`, `Kit de bancas`) y 'Electrónicos' (`Microondas`, `TV LED UHD 4K`, `Auriculares`, `Impresora`) aparecen frecuentemente en las listas de más vendidos, confirmando la popularidad de estas categorías.
# *   **Productos de nicho/especializados:** Libros y algunos instrumentos musicales (`Iniciando en programación`, `Ciencia de datos con Python`, `Guitarra acústica`, `Pandereta`, `Batería`, `Guitarra eléctrica`) aparecen en ambas listas (más y menos vendidos), lo que podría indicar que algunos de estos productos tienen un rendimiento muy específico dependiendo de la tienda.
# *   **Microondas:** Curiosamente, `Microondas` aparece como uno de los productos más vendidos en Tienda 1 y Tienda 2, pero también como uno de los menos vendidos en Tienda 3, mostrando una fluctuación en su demanda o disponibilidad.
# *   **Consistencia en algunos menos vendidos:** `Ciencia de datos con Python` y `Guitarra eléctrica` aparecen en las listas de menos vendidos en varias tiendas, lo que podría indicar una menor demanda general por estos artículos o que son productos de nicho con un público más limitado.
#
# Las visualizaciones de barras horizontales (`productos_totales.plot()`, `productos_totales2.plot()`, `productos_totales3.plot()`, `productos_totales4.plot()`) ofrecen una clara representación gráfica de estas diferencias, permitiendo identificar rápidamente los extremos en el rendimiento de los productos individuales de cada tienda.

# %% [markdown]
# ### Análisis del Costo de Envío Promedio
#
# Comparar los costos de envío promedio de cada tienda, lo cual puede ser un factor importante en la rentabilidad.

# %% [markdown]
# A continuación, se presenta el análisis del costo de envío promedio para cada tienda:
#
# *   **Tienda 1:** Costo de envío promedio = 26018.61
# *   **Tienda 2:** Costo de envío promedio = 25216.24
# *   **Tienda 3:** Costo de envío promedio = 24805.68
# *   **Tienda 4:** Costo de envío promedio = 23459.46
#
# Al comparar estos valores, podemos observar que la **Tienda 4** tiene el costo de envío promedio más bajo, con un valor de **23459.46**. Esto sugiere que la Tienda 4 podría tener una mayor eficiencia en sus operaciones logísticas o acuerdos de envío más favorables, lo que podría impactar positivamente su rentabilidad en comparación con las otras tiendas.

# %% [markdown]
# ## Conclusión y Recomendación
#
# Sintetizar todos los hallazgos de los análisis anteriores para formular una recomendación clara sobre a qué tienda debería vender el Sr. Juan, justificando la decisión con datos y razonamientos objetivos.

# %% [markdown]
# ### Recomendación al Sr. Juan:
#
# Considerando todos los análisis, **se recomienda al Sr. Juan que considere vender la Tienda 4.**
#
# **Justificación:**
#
# Aunque la Tienda 4 presenta el costo de envío promedio más bajo, lo cual es positivo para la eficiencia operativa, su **facturación total es significativamente la más baja** de las cuatro tiendas. En el contexto de una venta, un comprador generalmente buscará un negocio con un historial probado de ingresos robustos y un alto potencial de crecimiento. La facturación más baja de la Tienda 4 la hace el activo menos atractivo desde una perspectiva puramente financiera.
#
# Retener las Tiendas 1, 2 y 3 permitiría al Sr. Juan mantener activos con:
#
# *   **Tienda 1:** La mayor facturación, asegurando un flujo de ingresos principal.
# *   **Tienda 3:** La mejor reputación de clientes (calificación promedio de 4.05), lo cual es crucial para la lealtad y el crecimiento a largo plazo. Además, tiene un excelente rendimiento en la categoría de `Muebles`.
# *   **Tienda 2:** Un desempeño general sólido en facturación y calificaciones, sin ser la más débil en ninguna métrica importante.
#
# Al vender la Tienda 4, el Sr. Juan se desharía de la tienda con el rendimiento financiero más modesto, permitiéndole consolidar sus recursos y esfuerzos en las tiendas con mayor potencial de ingresos y reputación, optimizando así el valor total de su portafolio de negocios restante. La eficiencia en el costo de envío, aunque notable, no compensa la diferencia en la facturación total cuando el objetivo es vender uno de los activos.
